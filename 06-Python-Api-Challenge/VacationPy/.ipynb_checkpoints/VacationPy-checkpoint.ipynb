# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps

from config import gkey

# %%
gmaps.configure(api_key=gkey)

# %%
csv_path = ('../WeatherPy/Output/citys.csv')
city_df = pd.read_csv(csv_path)
city_df.head()
# Out:
#    Unnamed: 0       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           0  karpathos  35.5070  27.2132     59.00        77          20
# 1           1    margate  51.3813   1.3862     39.99        81           0
# 2           2    beecher  43.0900 -83.6944     25.00        74           1
# 3           3     albany  42.6001 -73.9662     28.00        56           1
# 4           4   camacupa -12.0167  17.4833     60.42        95         100
#
#    Wind Speed Country        Date
# 0        9.22      GR  1614321603
# 1        1.99      GB  1614321604
# 2        5.75      US  1614321604
# 3        3.51      US  1614321355
# 4        4.50      AO  1614321605

# %% [markdown]
# ### Create a heat map that displays the humidity for every city from the part I of the homework

# %%
coordinates = city_df[['Lat','Lng']].astype(float)
humidity = city_df['Humidity'].astype(float)

# %%
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
heat_layer = gmaps.heatmap_layer(locations = coordinates,
                                 weights=humidity,
                                 dissipating=False,
                                 max_intensity=400,
                                 point_radius = 5)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# #### SS of Heatmap
# <br>
# <br>
#
# ![heat_map.PNG](attachment:heat_map.PNG)

# %% [markdown]
# ### Narrow down the DataFrame to find your ideal weather condition. For example:

# %%
city_df
# Out:
#      Unnamed: 0              City      Lat       Lng  Max Temp  Humidity  \
# 0             0         karpathos  35.5070   27.2132     59.00        77
# 1             1           margate  51.3813    1.3862     39.99        81
# 2             2           beecher  43.0900  -83.6944     25.00        74
# 3             3            albany  42.6001  -73.9662     28.00        56
# 4             4          camacupa -12.0167   17.4833     60.42        95
# ..          ...               ...      ...       ...       ...       ...
# 541         541  kuala terengganu   5.3302  103.1408     89.60        62
# 542         542            latung   5.5000  120.8833     83.34        67
# 543         543          kirakira -10.4544  161.9205     82.15        81
# 544         544         marquette  46.5333  -87.6335     25.00        72
# 545         545            tromso  69.6496   18.9570     37.40        81
#
#      Cloudiness  Wind Speed Country        Date
# 0            20        9.22      GR  1614321603
# 1             0        1.99      GB  1614321604
# 2             1        5.75      US  1614321604
# 3             1        3.51      US  1614321355
# 4           100        4.50      AO  1614321605
# ..          ...         ...     ...         ...
# 541          20        9.22      MY  1614321768
# 542          94        1.07      PH  1614321768
# 543         100        5.41      SB  1614321769
# 544           0        9.62      US  1614321769
# 545          75       14.97      NO  1614321619
#
# [546 rows x 10 columns]

# %%
new_city_df = city_df.loc[(city_df["Max Temp"] < 100) & (city_df["Max Temp"] > 90) \
                                    & (city_df["Wind Speed"] < 10) \
                                    & (city_df["Cloudiness"] == 0)].dropna()
new_city_df.head()
# Out:
#      Unnamed: 0          City      Lat      Lng  Max Temp  Humidity  \
# 298         298     fatehabad  29.5167  75.4500     92.07        12
# 329         329          puri  19.8000  85.8500     96.80        14
# 442         442  mae hong son  19.3003  97.9685     91.40        31
# 490         490      khirkiya  22.1674  76.8605     93.97        12
# 520         520     bandarban  22.1965  92.2262     94.98        19
#
#      Cloudiness  Wind Speed Country        Date
# 298           0        9.73      IN  1614321696
# 329           0        1.14      IN  1614321610
# 442           0        4.21      TH  1614321739
# 490           0        8.84      IN  1614321753
# 520           0        6.24      BD  1614321763

# %%
len(new_city_df)
# Out:
# 5

# %%
hotel_df = new_city_df
hotel_df['Hotel Name'] = ""
hotel_df = hotel_df[['City', 'Lat', 'Lng', 'Max Temp', 'Wind Speed', 'Hotel Name']]
hotel_df
# Out:
#              City      Lat      Lng  Max Temp  Wind Speed Hotel Name
# 298     fatehabad  29.5167  75.4500     92.07        9.73
# 329          puri  19.8000  85.8500     96.80        1.14
# 442  mae hong son  19.3003  97.9685     91.40        4.21
# 490      khirkiya  22.1674  76.8605     93.97        8.84
# 520     bandarban  22.1965  92.2262     94.98        6.24

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
hotels = []

params = {
    'key': gkey,
    'radius': 5000,
    'keyword':'hotel'
}

for index, row in hotel_df.iterrows():
    
    lat = row['Lat']
    lng = row['Lng']    
    
    params["location"] = f"{lat},{lng}"
    
    response = requests.get(base_url, params=params)    
    response_json = response.json()
    
    try:
        hotel_df.loc[index, "Hotel Name"] = response_json['results'][0]['name']        
    
    except:
        print('No hotel found within radius!')

# %%
hotel_df
# Out:
#              City      Lat      Lng  Max Temp  Wind Speed  \
# 298     fatehabad  29.5167  75.4500     92.07        9.73
# 329          puri  19.8000  85.8500     96.80        1.14
# 442  mae hong son  19.3003  97.9685     91.40        4.21
# 490      khirkiya  22.1674  76.8605     93.97        8.84
# 520     bandarban  22.1965  92.2262     94.98        6.24
#
#                       Hotel Name
# 298    Hotel Park View By Amatra
# 329       MAYFAIR Heritage, Puri
# 442  Imperial Mae Hong Son Hotel
# 490                        Hotel
# 520    Nilachol Nilambori Resort

# %%
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
</dl>
"""
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)

fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# #### SS of Heatmap
# <br>
# <br>
#
# ![heat_map_2.PNG](attachment:heat_map_2.PNG)
