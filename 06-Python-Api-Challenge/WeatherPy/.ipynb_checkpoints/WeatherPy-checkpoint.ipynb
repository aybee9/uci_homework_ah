# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress

from config import api_key
from citipy import citipy

# %% [markdown]
# # Generate coordinates and retrieve cities

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90, high=90, size=1500)
lngs = np.random.uniform(low=-180, high=180, size=1500)
lat_lngs = zip(lats, lngs)

# retrieve cities base on coordinates 
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

print(len(cities))
# Out:
# 603

# %%
cities[0:10]
# Out:
# ['clyde river',
#  'luderitz',
#  'cabo san lucas',
#  'albany',
#  'rikitea',
#  'hualmay',
#  'meulaboh',
#  'hermanus',
#  'ushuaia',
#  'cape town']

# %% [markdown]
# # API calls

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?&units=Imperial"
query_url = base_url + "&appid=" + api_key + "&q="

# %%
city_count = 1 
city_data = [] # data for our dataframe

for city in cities:
    
    city_res = requests.get(query_url + city).json()
    
    print(f'Processing data for city number {city_count}:', city)
    
    try:
        lat = city_res["coord"]["lat"]
        lng = city_res["coord"]["lon"]
        max_temp = city_res["main"]["temp_max"]
        humidity = city_res["main"]["humidity"]
        clouds = city_res["clouds"]["all"]
        wind = city_res["wind"]["speed"]
        country = city_res["sys"]["country"]
        date = city_res["dt"]
        city_count +=1
        
        city_data.append({"City": city, 
                          "Lat": lat, 
                          "Lng": lng, 
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": clouds,
                          "Wind Speed": wind,
                          "Country": country,
                          "Date": date})
        
    except:
        print(f'No data found for {city}')
        city_count +=1
        pass

print('Process complete')
# Out:
# Processing data for city number 1: clyde river
# Processing data for city number 2: luderitz
# Processing data for city number 3: cabo san lucas
# Processing data for city number 4: albany
# Processing data for city number 5: rikitea
# Processing data for city number 6: hualmay
# Processing data for city number 7: meulaboh
# Processing data for city number 8: hermanus
# Processing data for city number 9: ushuaia
# Processing data for city number 10: cape town
# Processing data for city number 11: taolanaro
# No data found for taolanaro
# Processing data for city number 12: haines junction
# Processing data for city number 13: suao
# No data found for suao
# Processing data for city number 14: kaitangata
# Processing data for city number 15: kaputa
# Processing data for city number 16: garavuti
# Processing data for city number 17: aksu
# Processing data for city number 18: belushya guba
# No data found for belushya guba
# Processing data for city number 19: aklavik
# Processing data for city number 20: bam
# Processing data for city number 21: bengkulu
# Processing data for city number 22: bluff
# Processing data for city number 23: carutapera
# Processing data for city number 24: jiangyou
# Processing data for city number 25: tuatapere
# Processing data for city number 26: nanortalik
# Processing data for city number 27: bowen
# Processing data for city number 28: hobart
# Processing data for city number 29: sao felix do xingu
# Processing data for city number 30: thompson
# Processing data for city number 31: sisimiut
# Processing data for city number 32: busselton
# Processing data for city number 33: sola
# Processing data for city number 34: port elizabeth
# Processing data for city number 35: yellowknife
# Processing data for city number 36: springdale
# Processing data for city number 37: butaritari
# Processing data for city number 38: halalo
# No data found for halalo
# Processing data for city number 39: port alfred
# Processing data for city number 40: tuktoyaktuk
# Processing data for city number 41: cidreira
# Processing data for city number 42: qaanaaq
# Processing data for city number 43: omboue
# Processing data for city number 44: provideniya
# Processing data for city number 45: redcar
# Processing data for city number 46: nizhneyansk
# No data found for nizhneyansk
# Processing data for city number 47: kruisfontein
# Processing data for city number 48: jatoi
# No data found for jatoi
# Processing data for city number 49: honiara
# Processing data for city number 50: ponta do sol
# Processing data for city number 51: dalvik
# Processing data for city number 52: salalah
# Processing data for city number 53: sao filipe
# Processing data for city number 54: bredasdorp
# Processing data for city number 55: mataura
# Processing data for city number 56: vaini
# Processing data for city number 509: ampanihy
# Processing data for city number 510: cody
# Processing data for city number 511: torbay
# Processing data for city number 512: angoche
# Processing data for city number 513: honningsvag
# Processing data for city number 514: krasnoselkup
# Processing data for city number 515: laiagam
# No data found for laiagam
# Processing data for city number 516: quatre cocos
# Processing data for city number 517: kieta
# Processing data for city number 518: vestmanna
# Processing data for city number 519: shahdol
# Processing data for city number 520: qiongshan
# Processing data for city number 521: klaksvik
# Processing data for city number 522: belmonte
# Processing data for city number 523: new iberia
# Processing data for city number 524: birjand
# Processing data for city number 525: mabaruma
# Processing data for city number 526: amahai
# Processing data for city number 527: guarda
# Processing data for city number 528: olinda
# Processing data for city number 529: kilindoni
# Processing data for city number 530: pouebo
# Processing data for city number 531: leini
# Processing data for city number 532: paka
# Processing data for city number 533: vilyuysk
# Processing data for city number 534: vardo
# Processing data for city number 535: kologriv
# Processing data for city number 536: karachi
# Processing data for city number 537: fukuma
# Processing data for city number 538: puerto escondido
# Processing data for city number 539: andrelandia
# Processing data for city number 540: villaviciosa
# Processing data for city number 541: jiwani
# Processing data for city number 542: nome
# Processing data for city number 543: taunggyi
# Processing data for city number 544: darnah
# Processing data for city number 545: ngukurr
# No data found for ngukurr
# Processing data for city number 546: sandwick
# Processing data for city number 547: khash
# Processing data for city number 548: watsa
# Processing data for city number 549: viedma
# Processing data for city number 550: kingman
# Processing data for city number 551: port hedland
# Processing data for city number 552: doka
# Processing data for city number 553: ekibastuz
# Processing data for city number 554: kamenka
# Processing data for city number 555: peniche
# Processing data for city number 556: sorland
# Processing data for city number 557: sao gabriel da cachoeira
# Processing data for city number 558: cutro
# Processing data for city number 559: washington
# Processing data for city number 560: wundanyi
# Processing data for city number 561: port blair
# Processing data for city number 562: kutum
# Processing data for city number 563: oyama
# Processing data for city number 564: puerto narino
# Processing data for city number 565: norrtalje
# Processing data for city number 566: gaoua
# Processing data for city number 567: borinskoye
# Processing data for city number 568: obo
# Processing data for city number 569: faya
# Processing data for city number 570: puerto ayacucho
# Processing data for city number 571: bantou
# Processing data for city number 572: heihe
# Processing data for city number 573: grand-lahou
# Processing data for city number 574: lufilufi
# Processing data for city number 575: marktoberdorf
# Processing data for city number 576: lasa
# Processing data for city number 577: kommunisticheskiy
# Processing data for city number 578: altay
# Processing data for city number 579: north bend
# Processing data for city number 580: belgrade
# Processing data for city number 581: piopio
# Processing data for city number 582: zhanaozen
# Processing data for city number 583: itupiranga
# Processing data for city number 584: bartica
# Processing data for city number 585: ambovombe
# Processing data for city number 586: robertsport
# Processing data for city number 587: damoh
# Processing data for city number 588: coos bay
# Processing data for city number 589: shebunino
# Processing data for city number 590: samarai
# Processing data for city number 591: chaiyaphum
# Processing data for city number 592: vinstra
# Processing data for city number 593: ayr
# Processing data for city number 594: akyab
# Processing data for city number 595: crotone
# Processing data for city number 596: zaozerne
# Processing data for city number 597: ambon
# Processing data for city number 598: porto novo
# Processing data for city number 599: teguajinal
# Processing data for city number 600: inirida
# Processing data for city number 601: kamensk-shakhtinskiy
# Processing data for city number 602: srednekolymsk
# Processing data for city number 603: palmer
# Process complete

# %% [markdown]
# #### Pandas Data Frame

# %%
city_df = pd.DataFrame(city_data)
city_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     clyde river  70.4692  -68.5914     -7.60        77          90
# 1        luderitz -26.6481   15.1594     63.88        70           0
# 2  cabo san lucas  22.8909 -109.9124     69.80        19          20
# 3          albany  42.6001  -73.9662     28.99        44           0
# 4         rikitea -23.1203 -134.9692     78.37        84          93
#
#    Wind Speed Country        Date
# 0       24.16      CA  1614314327
# 1       10.96      NA  1614314327
# 2        5.75      MX  1614314192
# 3        1.99      US  1614314328
# 4       16.78      PF  1614314328

# %%
city_df.count()
city_df.to_csv('Output/citys.csv')

# %%
lats = city_df["Lat"]
max_temps = city_df["Max Temp"]
humidity = city_df["Humidity"]
cloudiness = city_df["Cloudiness"]
wind_speed = city_df["Wind Speed"]

# %%
print(f'The max humidity in any city is: {humidity.max()}')
# Out:
# The max humidity in any city is: 100

# %% [markdown]
# # Scatter Plots

# %% [markdown]
# #### Temperature (F) vs. Latitude

# %%
plt.scatter(lats, max_temps)
plt.title('Temperature vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Temperature °F')
plt.grid(True)
plt.savefig('Output/lat_temp.png', bbox_inches='tight')

# %% [markdown]
# In this scatter plot we can see that as the latitude moves away from zero, the temperature begins to drop also.

# %% [markdown]
# #### Humidity (%) vs. Latitude

# %%
plt.scatter(lats, humidity)
plt.title('City Humidity vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(True)
plt.savefig('Output/hum_lat.png',bbox_inches='tight')

# %% [markdown]
# We see no real relationship between latitude and humidity

# %% [markdown]
# #### Cloudiness (%) vs. Latitude

# %%
plt.scatter(lats, cloudiness)
plt.title('Cloudiness vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(True)
plt.savefig('Output/cloud_lat.png',bbox_inches='tight')

# %% [markdown]
# As with humidity and latitude, we see no real relationship between cloudiness and latitude either

# %% [markdown]
# #### Wind Speed (mph) vs. Latitude

# %%
plt.scatter(lats, wind_speed)
plt.title('Wind Speed (mph) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)
plt.savefig('Output/wind_lats.png',bbox_inches='tight')

# %% [markdown]
# The data shows wind speed did not change depending on latitude

# %% [markdown]
# # Linear Regression

# %%
def linear_regression(x_values, y_values, title, text_coordinates):    
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"R-value is: {rvalue**2}")
    plt.show()

# %%
north_hemi_df = city_df.loc[(city_df["Lat"] >= 0)]
south_hemi_df = city_df.loc[(city_df["Lat"] < 0)]

# %% [markdown]
# #### Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Max Temp"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# R-value is: 0.703898647028578

# %% [markdown]
# `There is a strong negative correlation. The graph indicates, as latitude increases, temperature decreases`

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Max Temp"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# R-value is: 0.29953836113843463

# %% [markdown]
# `There is a positive corellation: as you get closes to the equator the temperature increases`

# %% [markdown]
# #### Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Humidity"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# R-value is: 0.15299909714972032

# %% [markdown]
# `There is no strong correlation between humidity and latitude`

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Humidity"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# R-value is: 0.10771539080473011

# %% [markdown]
# `There is no strong correlation between humidity and latitude`

# %% [markdown]
# #### Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Cloudiness"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# R-value is: 0.06983392237631483

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Cloudiness"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# R-value is: 0.05288643854477526

# %% [markdown]
# `There is no strong correlation between cloudiness and latitude`

# %% [markdown]
# ####  Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Wind Speed"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# R-value is: 0.01034035223639293

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Wind Speed"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# R-value is: 0.05871588792254228

# %% [markdown]
# `There is no strong correlation between wind speed and latitude`
