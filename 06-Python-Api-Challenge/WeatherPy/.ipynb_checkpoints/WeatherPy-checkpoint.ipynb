# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress

from config import api_key
from citipy import citipy

# %% [markdown]
# #### Generate coordinates and retrieve city list

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90, high=90, size=1500)
lngs = np.random.uniform(low=-180, high=180, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 595

# %% [markdown]
# #### API calls

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?&units=Imperial"
query_url = base_url + "&appid=" + api_key + "&q="

# %%
city_count = 1 
city_data = []

for city in cities:
    
    city_res = requests.get(query_url + city).json()
    
    print(f'Processing data for city number {city_count}:', {city})
    
    try:
        lat = city_res["coord"]["lat"]
        lng = city_res["coord"]["lon"]
        max_temp = city_res["main"]["temp_max"]
        humidity = city_res["main"]["humidity"]
        clouds = city_res["clouds"]["all"]
        wind = city_res["wind"]["speed"]
        country = city_res["sys"]["country"]
        date = city_res["dt"]
        city_count +=1
        
        city_data.append({"City": city, 
                          "Lat": lat, 
                          "Lng": lng, 
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": clouds,
                          "Wind Speed": wind,
                          "Country": country,
                          "Date": date})
        
    except:
        print(f'No data found for {city}')
        city_count +=1
        pass

print('Process complete')
# Out:
# Processing data for city number 1: {'olinda'}
# Processing data for city number 2: {'pochutla'}
# Processing data for city number 3: {'tamiahua'}
# Processing data for city number 4: {'chuy'}
# Processing data for city number 5: {'butaritari'}
# Processing data for city number 6: {'bichura'}
# Processing data for city number 7: {'bathsheba'}
# Processing data for city number 8: {'ballarat'}
# Processing data for city number 9: {'taolanaro'}
# No data found for taolanaro
# Processing data for city number 10: {'rikitea'}
# Processing data for city number 11: {'narsaq'}
# Processing data for city number 12: {'poum'}
# Processing data for city number 13: {'illoqqortoormiut'}
# No data found for illoqqortoormiut
# Processing data for city number 14: {'saint-joseph'}
# Processing data for city number 15: {'sasaguri'}
# Processing data for city number 16: {'punta arenas'}
# Processing data for city number 17: {'ushuaia'}
# Processing data for city number 18: {'broome'}
# Processing data for city number 19: {'mar del plata'}
# Processing data for city number 20: {'yenagoa'}
# Processing data for city number 21: {'marcona'}
# No data found for marcona
# Processing data for city number 22: {'vaini'}
# Processing data for city number 23: {'havre-saint-pierre'}
# Processing data for city number 24: {'tiksi'}
# Processing data for city number 25: {'mahebourg'}
# Processing data for city number 26: {'xapuri'}
# Processing data for city number 27: {'bubaque'}
# Processing data for city number 28: {'flinders'}
# Processing data for city number 29: {'arraial do cabo'}
# Processing data for city number 30: {'kruisfontein'}
# Processing data for city number 31: {'itoman'}
# Processing data for city number 32: {'qaanaaq'}
# Processing data for city number 33: {'east london'}
# Processing data for city number 34: {'fakel'}
# Processing data for city number 35: {'naze'}
# Processing data for city number 36: {'caltagirone'}
# Processing data for city number 37: {'longyearbyen'}
# Processing data for city number 38: {'new norfolk'}
# Processing data for city number 39: {'busselton'}
# Processing data for city number 40: {'aleksandrov gay'}
# Processing data for city number 41: {'yellowknife'}
# Processing data for city number 42: {'puerto ayora'}
# Processing data for city number 43: {'rolim de moura'}
# No data found for rolim de moura
# Processing data for city number 44: {'hermanus'}
# Processing data for city number 45: {'belushya guba'}
# No data found for belushya guba
# Processing data for city number 46: {'talnakh'}
# Processing data for city number 47: {'nikolskoye'}
# Processing data for city number 48: {'barrow'}
# Processing data for city number 49: {'sao filipe'}
# Processing data for city number 50: {'hilo'}
# Processing data for city number 51: {'tuktoyaktuk'}
# Processing data for city number 52: {'kaitangata'}
# Processing data for city number 53: {'jamestown'}
# Processing data for city number 54: {'hit'}
# Processing data for city number 55: {'shingu'}
# Processing data for city number 56: {'vaitupu'}
# No data found for vaitupu
# Processing data for city number 57: {'palabuhanratu'}
# No data found for palabuhanratu
# Processing data for city number 58: {'phan rang'}
# No data found for phan rang
# Processing data for city number 59: {'yulara'}
# Processing data for city number 60: {'georgetown'}
# Processing data for city number 61: {'faya'}
# Processing data for city number 62: {'prince rupert'}
# Processing data for city number 63: {'kodiak'}
# Processing data for city number 64: {'qaqortoq'}
# Processing data for city number 65: {'west wendover'}
# Processing data for city number 66: {'kirakira'}
# Processing data for city number 67: {'hithadhoo'}
# Processing data for city number 68: {'tsihombe'}
# No data found for tsihombe
# Processing data for city number 69: {'walvis bay'}
# Processing data for city number 70: {'coquimbo'}
# Processing data for city number 71: {'kloulklubed'}
# Processing data for city number 72: {'gushikawa'}
# Processing data for city number 73: {'dikson'}
# Processing data for city number 74: {'cape town'}
# Processing data for city number 75: {'belyy yar'}
# Processing data for city number 76: {'lavrentiya'}
# Processing data for city number 77: {'okato'}
# Processing data for city number 78: {'mataura'}
# Processing data for city number 79: {'khorixas'}
# Processing data for city number 80: {'atuona'}
# Processing data for city number 81: {'ksenyevka'}
# No data found for ksenyevka
# Processing data for city number 82: {'port alfred'}
# Processing data for city number 83: {'victoria'}
# Processing data for city number 84: {'turayf'}
# Processing data for city number 85: {'saskylakh'}
# Processing data for city number 86: {'khatanga'}
# Processing data for city number 87: {'saint-pierre'}
# Processing data for city number 88: {'sabha'}
# Processing data for city number 89: {'luderitz'}
# Processing data for city number 90: {'honningsvag'}
# Processing data for city number 91: {'cherskiy'}
# Processing data for city number 92: {'callaguip'}
# Processing data for city number 93: {'qeshm'}
# Processing data for city number 94: {'maningrida'}
# Processing data for city number 95: {'san quintin'}
# Processing data for city number 96: {'saint-philippe'}
# Processing data for city number 97: {'zaysan'}
# Processing data for city number 98: {'bilibino'}
# Processing data for city number 99: {'bethel'}
# Processing data for city number 100: {'vestmannaeyjar'}
# Processing data for city number 101: {'avarua'}
# Processing data for city number 102: {'gorno-chuyskiy'}
# No data found for gorno-chuyskiy
# Processing data for city number 103: {'maragogi'}
# Processing data for city number 104: {'vao'}
# Processing data for city number 105: {'passy'}
# Processing data for city number 106: {'isangel'}
# Processing data for city number 107: {'iralaya'}
# Processing data for city number 108: {'northam'}
# Processing data for city number 109: {'clyde river'}
# Processing data for city number 110: {'iqaluit'}
# Processing data for city number 111: {'codrington'}
# Processing data for city number 112: {'ponta do sol'}
# Processing data for city number 113: {'bud'}
# Processing data for city number 114: {'kampot'}
# Processing data for city number 115: {'benguela'}
# Processing data for city number 116: {'ostrovnoy'}
# Processing data for city number 117: {'mwanza'}
# Processing data for city number 118: {'moose factory'}
# Processing data for city number 119: {'ulladulla'}
# Processing data for city number 120: {'chokurdakh'}
# Processing data for city number 121: {'albany'}
# Processing data for city number 122: {'san jose'}
# Processing data for city number 123: {'souillac'}
# Processing data for city number 124: {'osoyoos'}
# Processing data for city number 125: {'eyl'}
# Processing data for city number 126: {'olafsvik'}
# Processing data for city number 127: {'ilulissat'}
# Processing data for city number 128: {'seoul'}
# Processing data for city number 129: {'bandarbeyla'}
# Processing data for city number 130: {'villa maria'}
# Processing data for city number 131: {'zheleznodorozhnyy'}
# Processing data for city number 132: {'te anau'}
# Processing data for city number 133: {'bela vista'}
# Processing data for city number 134: {'airai'}
# Processing data for city number 135: {'madimba'}
# Processing data for city number 136: {'lebu'}
# Processing data for city number 137: {'neepawa'}
# Processing data for city number 138: {'makakilo city'}
# Processing data for city number 139: {'porto novo'}
# Processing data for city number 140: {'kieta'}
# Processing data for city number 141: {'bluff'}
# Processing data for city number 142: {'richards bay'}
# Processing data for city number 143: {'margate'}
# Processing data for city number 144: {'xinyang'}
# Processing data for city number 145: {'hay river'}
# Processing data for city number 146: {'kupang'}
# Processing data for city number 147: {'samusu'}
# No data found for samusu
# Processing data for city number 148: {'polunochnoye'}
# Processing data for city number 149: {'macapa'}
# Processing data for city number 150: {'belaya gora'}
# Processing data for city number 151: {'marigot'}
# Processing data for city number 152: {'ocampo'}
# Processing data for city number 153: {'mount isa'}
# Processing data for city number 154: {'hobart'}
# Processing data for city number 155: {'amderma'}
# No data found for amderma
# Processing data for city number 156: {'sergeyevka'}
# Processing data for city number 157: {'fortuna'}
# Processing data for city number 158: {'verkhnevilyuysk'}
# Processing data for city number 159: {'mys shmidta'}
# No data found for mys shmidta
# Processing data for city number 160: {'upernavik'}
# Processing data for city number 161: {'xinmin'}
# Processing data for city number 162: {'auki'}
# Processing data for city number 163: {'xining'}
# Processing data for city number 164: {'cap malheureux'}
# Processing data for city number 165: {'sadove'}
# Processing data for city number 166: {'hambantota'}
# Processing data for city number 167: {'soanierana ivongo'}
# Processing data for city number 168: {'raudeberg'}
# Processing data for city number 169: {'bredasdorp'}
# Processing data for city number 170: {'alekseyevsk'}
# Processing data for city number 171: {'poli'}
# Processing data for city number 172: {'hasaki'}
# Processing data for city number 173: {'kracheh'}
# No data found for kracheh
# Processing data for city number 174: {'saleaula'}
# No data found for saleaula
# Processing data for city number 175: {'carnarvon'}
# Processing data for city number 176: {'kharovsk'}
# Processing data for city number 177: {'hami'}
# Processing data for city number 178: {'bembereke'}
# Processing data for city number 179: {'steamboat springs'}
# Processing data for city number 180: {'xicotencatl'}
# Processing data for city number 181: {'vostok'}
# Processing data for city number 182: {'gbarnga'}
# Processing data for city number 183: {'phek'}
# Processing data for city number 184: {'cabo san lucas'}
# Processing data for city number 185: {'karkaralinsk'}
# No data found for karkaralinsk
# Processing data for city number 186: {'araria'}
# Processing data for city number 187: {'cravo norte'}
# Processing data for city number 188: {'kahului'}
# Processing data for city number 189: {'faanui'}
# Processing data for city number 190: {'vanimo'}
# Processing data for city number 191: {'amzya'}
# Processing data for city number 192: {'saldanha'}
# Processing data for city number 193: {'itarema'}
# Processing data for city number 194: {'meulaboh'}
# Processing data for city number 195: {'saint george'}
# Processing data for city number 196: {'provideniya'}
# Processing data for city number 197: {'komatipoort'}
# Processing data for city number 198: {'severo-kurilsk'}
# Processing data for city number 199: {'aksu'}
# Processing data for city number 200: {'iglino'}
# Processing data for city number 201: {'nanortalik'}
# Processing data for city number 202: {'helong'}
# Processing data for city number 203: {'channel-port aux basques'}
# Processing data for city number 204: {'barentsburg'}
# No data found for barentsburg
# Processing data for city number 205: {'saint-augustin'}
# Processing data for city number 206: {'pacific grove'}
# Processing data for city number 207: {'hobyo'}
# Processing data for city number 208: {'grand river south east'}
# No data found for grand river south east
# Processing data for city number 209: {'mombetsu'}
# Processing data for city number 210: {'resistencia'}
# Processing data for city number 211: {'tura'}
# Processing data for city number 212: {'ambilobe'}
# Processing data for city number 213: {'college'}
# Processing data for city number 214: {'roald'}
# Processing data for city number 215: {'copiapo'}
# Processing data for city number 216: {'nome'}
# Processing data for city number 217: {'polyarnyy'}
# Processing data for city number 218: {'ornskoldsvik'}
# Processing data for city number 219: {'hervey bay'}
# Processing data for city number 220: {'morant bay'}
# Processing data for city number 221: {'tallahassee'}
# Processing data for city number 222: {'beloha'}
# Processing data for city number 223: {'mandan'}
# Processing data for city number 224: {'xuddur'}
# Processing data for city number 225: {'tromso'}
# Processing data for city number 226: {'petropavlovsk-kamchatskiy'}
# Processing data for city number 227: {'maniitsoq'}
# Processing data for city number 228: {'sentyabrskiy'}
# No data found for sentyabrskiy
# Processing data for city number 229: {'kingsville'}
# Processing data for city number 230: {'kanniyakumari'}
# Processing data for city number 231: {'vila franca do campo'}
# Processing data for city number 232: {'jalu'}
# Processing data for city number 233: {'galgani'}
# No data found for galgani
# Processing data for city number 234: {'aklavik'}
# Processing data for city number 235: {'andenes'}
# Processing data for city number 236: {'springbok'}
# Processing data for city number 237: {'bara'}
# Processing data for city number 238: {'sistranda'}
# Processing data for city number 239: {'klaksvik'}
# Processing data for city number 240: {'thompson'}
# Processing data for city number 241: {'leningradskiy'}
# Processing data for city number 242: {'port shepstone'}
# Processing data for city number 243: {'maun'}
# Processing data for city number 244: {'ahipara'}
# Processing data for city number 245: {'denpasar'}
# Processing data for city number 246: {'shimanovsk'}
# Processing data for city number 247: {'husavik'}
# Processing data for city number 248: {'morondava'}
# Processing data for city number 249: {'los llanos de aridane'}
# Processing data for city number 250: {'bambous virieux'}
# Processing data for city number 251: {'quelimane'}
# Processing data for city number 252: {'chapais'}
# Processing data for city number 253: {'puerto escondido'}
# Processing data for city number 254: {'port elizabeth'}
# Processing data for city number 255: {'kulhudhuffushi'}
# Processing data for city number 256: {'merritt'}
# Processing data for city number 257: {'sola'}
# Processing data for city number 258: {'bolungarvik'}
# No data found for bolungarvik
# Processing data for city number 259: {'srednekolymsk'}
# Processing data for city number 260: {'coffs harbour'}
# Processing data for city number 261: {'kolyvan'}
# Processing data for city number 262: {'nara'}
# Processing data for city number 263: {'karaul'}
# No data found for karaul
# Processing data for city number 264: {'pevek'}
# Processing data for city number 265: {'pervoye maya'}
# Processing data for city number 266: {'north bend'}
# Processing data for city number 267: {'powell'}
# Processing data for city number 268: {'kapaa'}
# Processing data for city number 269: {'karaton'}
# Processing data for city number 270: {'kousseri'}
# Processing data for city number 271: {'orbetello'}
# Processing data for city number 272: {'castro'}
# Processing data for city number 273: {'eydhafushi'}
# Processing data for city number 274: {'balkanabat'}
# Processing data for city number 275: {'asasa'}
# Processing data for city number 276: {'dudinka'}
# Processing data for city number 277: {'novyy urengoy'}
# Processing data for city number 278: {'marfino'}
# Processing data for city number 279: {'billings'}
# Processing data for city number 280: {'devarkonda'}
# Processing data for city number 281: {'bon air'}
# Processing data for city number 282: {'kenai'}
# Processing data for city number 283: {'fuyang'}
# Processing data for city number 284: {'champerico'}
# Processing data for city number 285: {'maghama'}
# No data found for maghama
# Processing data for city number 286: {'qurbah'}
# No data found for qurbah
# Processing data for city number 287: {'stornoway'}
# Processing data for city number 288: {'elko'}
# Processing data for city number 289: {'coahuayana'}
# Processing data for city number 290: {'ljubovija'}
# Processing data for city number 291: {'bengkulu'}
# Processing data for city number 292: {'samalaeulu'}
# No data found for samalaeulu
# Processing data for city number 293: {'solikamsk'}
# Processing data for city number 294: {'aksarka'}
# Processing data for city number 295: {'kavieng'}
# Processing data for city number 296: {'pisco'}
# Processing data for city number 297: {'san giovanni in fiore'}
# Processing data for city number 298: {'sao jose da coroa grande'}
# Processing data for city number 299: {'huazolotitlan'}
# No data found for huazolotitlan
# Processing data for city number 300: {'khani'}
# Processing data for city number 301: {'constitucion'}
# Processing data for city number 302: {'antalaha'}
# Processing data for city number 303: {'rincon'}
# Processing data for city number 304: {'point pleasant'}
# Processing data for city number 305: {'ganzhou'}
# Processing data for city number 306: {'unirea'}
# Processing data for city number 307: {'saint-paul'}
# Processing data for city number 308: {'kemijarvi'}
# Processing data for city number 309: {'songea'}
# Processing data for city number 310: {'sabang'}
# Processing data for city number 311: {'chernyshevskiy'}
# Processing data for city number 312: {'hailey'}
# Processing data for city number 313: {'ribeira grande'}
# Processing data for city number 314: {'egvekinot'}
# Processing data for city number 315: {'yokadouma'}
# Processing data for city number 316: {'derzhavinsk'}
# Processing data for city number 317: {'touros'}
# Processing data for city number 318: {'rocha'}
# Processing data for city number 319: {'muravlenko'}
# Processing data for city number 320: {'new london'}
# Processing data for city number 321: {'bonthe'}
# Processing data for city number 322: {'tasiilaq'}
# Processing data for city number 323: {'pizarro'}
# Processing data for city number 324: {'lompoc'}
# Processing data for city number 325: {'rochegda'}
# Processing data for city number 326: {'teguldet'}
# Processing data for city number 327: {'saint-louis'}
# Processing data for city number 328: {'pitimbu'}
# Processing data for city number 329: {'aflu'}
# No data found for aflu
# Processing data for city number 330: {'teya'}
# Processing data for city number 331: {'beyneu'}
# Processing data for city number 332: {'qingan'}
# No data found for qingan
# Processing data for city number 333: {'bektemir'}
# Processing data for city number 334: {'abomsa'}
# Processing data for city number 335: {'grand gaube'}
# Processing data for city number 336: {'norman wells'}
# Processing data for city number 337: {'barranca'}
# Processing data for city number 338: {'namatanai'}
# Processing data for city number 339: {'labuhan'}
# Processing data for city number 340: {'ende'}
# Processing data for city number 341: {'namibe'}
# Processing data for city number 342: {'uyuni'}
# Processing data for city number 343: {'mabaruma'}
# Processing data for city number 344: {'lac du bonnet'}
# Processing data for city number 345: {'lorengau'}
# Processing data for city number 346: {'maarianhamina'}
# Processing data for city number 347: {'nizhneyansk'}
# No data found for nizhneyansk
# Processing data for city number 348: {'mareeba'}
# Processing data for city number 349: {'jidong'}
# Processing data for city number 350: {'baiyin'}
# Processing data for city number 351: {'san patricio'}
# Processing data for city number 352: {'sao joao da barra'}
# Processing data for city number 353: {'burns lake'}
# Processing data for city number 354: {'sorvag'}
# No data found for sorvag
# Processing data for city number 355: {'vredendal'}
# Processing data for city number 356: {'usinsk'}
# Processing data for city number 357: {'vagur'}
# Processing data for city number 358: {'inuvik'}
# Processing data for city number 359: {'clermont'}
# Processing data for city number 360: {'grindavik'}
# Processing data for city number 361: {'cidreira'}
# Processing data for city number 362: {'tabou'}
# Processing data for city number 363: {'kutum'}
# Processing data for city number 364: {'havelock'}
# Processing data for city number 365: {'ouadda'}
# Processing data for city number 366: {'vaitape'}
# Processing data for city number 367: {'sala'}
# Processing data for city number 368: {'torbay'}
# Processing data for city number 369: {'beneditinos'}
# Processing data for city number 370: {'caravelas'}
# Processing data for city number 371: {'vardo'}
# Processing data for city number 372: {'ginir'}
# Processing data for city number 373: {'sitka'}
# Processing data for city number 374: {'kushima'}
# Processing data for city number 375: {'moerai'}
# Processing data for city number 376: {'bafoulabe'}
# Processing data for city number 377: {'tabukiniberu'}
# No data found for tabukiniberu
# Processing data for city number 378: {'hofn'}
# Processing data for city number 379: {'brae'}
# Processing data for city number 380: {'tuatapere'}
# Processing data for city number 381: {'taywarah'}
# Processing data for city number 382: {'ancud'}
# Processing data for city number 383: {'bagdarin'}
# Processing data for city number 384: {'asau'}
# Processing data for city number 385: {'awjilah'}
# Processing data for city number 386: {'port augusta'}
# Processing data for city number 387: {'mouzakion'}
# No data found for mouzakion
# Processing data for city number 388: {'crestview'}
# Processing data for city number 389: {'pangnirtung'}
# Processing data for city number 390: {'nguiu'}
# No data found for nguiu
# Processing data for city number 391: {'marsa matruh'}
# Processing data for city number 392: {'barawe'}
# No data found for barawe
# Processing data for city number 393: {'lev tolstoy'}
# Processing data for city number 394: {'upington'}
# Processing data for city number 395: {'keetmanshoop'}
# Processing data for city number 396: {'myski'}
# Processing data for city number 397: {'middelkerke'}
# Processing data for city number 398: {'shimoda'}
# Processing data for city number 399: {'trairi'}
# Processing data for city number 400: {'sibolga'}
# Processing data for city number 401: {'casper'}
# Processing data for city number 402: {'paradwip'}
# No data found for paradwip
# Processing data for city number 403: {'indianola'}
# Processing data for city number 404: {'bonito'}
# Processing data for city number 405: {'tessalit'}
# Processing data for city number 406: {'ponta delgada'}
# Processing data for city number 407: {'padang'}
# Processing data for city number 408: {'santa maria'}
# Processing data for city number 409: {'mnogovershinnyy'}
# Processing data for city number 410: {'aljezur'}
# Processing data for city number 411: {'sena madureira'}
# Processing data for city number 412: {'nantucket'}
# Processing data for city number 413: {'santa eulalia del rio'}
# No data found for santa eulalia del rio
# Processing data for city number 414: {'voh'}
# Processing data for city number 415: {'kualakapuas'}
# Processing data for city number 416: {'cururupu'}
# Processing data for city number 417: {'salalah'}
# Processing data for city number 418: {'satitoa'}
# No data found for satitoa
# Processing data for city number 419: {'cockburn town'}
# Processing data for city number 420: {'zhuhai'}
# Processing data for city number 421: {'aykhal'}
# Processing data for city number 422: {'erdenet'}
# Processing data for city number 423: {'gazanjyk'}
# Processing data for city number 424: {'gimli'}
# Processing data for city number 425: {'mananjary'}
# Processing data for city number 426: {'atar'}
# Processing data for city number 427: {'portland'}
# Processing data for city number 428: {'chikoy'}
# No data found for chikoy
# Processing data for city number 429: {'mani'}
# Processing data for city number 430: {'privas'}
# Processing data for city number 431: {'port-gentil'}
# Processing data for city number 432: {'paamiut'}
# Processing data for city number 433: {'pampa'}
# Processing data for city number 434: {'junin'}
# Processing data for city number 435: {'gualaceo'}
# Processing data for city number 436: {'phalodi'}
# Processing data for city number 437: {'katsuura'}
# Processing data for city number 438: {'cervo'}
# Processing data for city number 439: {'torbat-e jam'}
# Processing data for city number 440: {'nueva germania'}
# Processing data for city number 441: {'talaya'}
# Processing data for city number 442: {'samarai'}
# Processing data for city number 443: {'manggar'}
# Processing data for city number 444: {'banda aceh'}
# Processing data for city number 445: {'balimo'}
# No data found for balimo
# Processing data for city number 446: {'loreto'}
# Processing data for city number 447: {'burnie'}
# Processing data for city number 448: {'richard toll'}
# No data found for richard toll
# Processing data for city number 449: {'mus'}
# Processing data for city number 450: {'palotina'}
# Processing data for city number 451: {'mackenzie'}
# Processing data for city number 452: {'ibotirama'}
# Processing data for city number 453: {'attawapiskat'}
# No data found for attawapiskat
# Processing data for city number 454: {'novyy urgal'}
# Processing data for city number 455: {'warqla'}
# No data found for warqla
# Processing data for city number 456: {'krumovgrad'}
# Processing data for city number 457: {'mana'}
# Processing data for city number 458: {'gamba'}
# Processing data for city number 459: {'tawkar'}
# No data found for tawkar
# Processing data for city number 460: {'leshukonskoye'}
# Processing data for city number 461: {'sechura'}
# Processing data for city number 462: {'zacualpan'}
# Processing data for city number 463: {'alta floresta'}
# Processing data for city number 464: {'boueni'}
# Processing data for city number 465: {'nyurba'}
# Processing data for city number 466: {'aktau'}
# Processing data for city number 467: {'cairns'}
# Processing data for city number 468: {'haguenau'}
# Processing data for city number 469: {'nizwa'}
# Processing data for city number 470: {'nuqui'}
# Processing data for city number 471: {'three hills'}
# Processing data for city number 472: {'cap-aux-meules'}
# Processing data for city number 473: {'san cristobal'}
# Processing data for city number 474: {'durazno'}
# Processing data for city number 475: {'guerrero negro'}
# Processing data for city number 476: {'babanusah'}
# No data found for babanusah
# Processing data for city number 477: {'opuwo'}
# Processing data for city number 478: {'duki'}
# Processing data for city number 479: {'suez'}
# Processing data for city number 480: {'vershino-shakhtaminskiy'}
# Processing data for city number 481: {'high level'}
# Processing data for city number 482: {'biltine'}
# Processing data for city number 483: {'nuuk'}
# Processing data for city number 484: {'soyo'}
# Processing data for city number 485: {'okhotsk'}
# Processing data for city number 486: {'waingapu'}
# Processing data for city number 487: {'awbari'}
# Processing data for city number 488: {'safranbolu'}
# Processing data for city number 489: {'duku'}
# Processing data for city number 490: {'haines junction'}
# Processing data for city number 491: {'tanabe'}
# Processing data for city number 492: {'port-cartier'}
# Processing data for city number 493: {'avera'}
# Processing data for city number 494: {'aripuana'}
# Processing data for city number 495: {'mandalgovi'}
# Processing data for city number 496: {'sur'}
# Processing data for city number 497: {'zeya'}
# Processing data for city number 498: {'erenhot'}
# Processing data for city number 499: {'muta'}
# Processing data for city number 500: {'alcudia'}
# Processing data for city number 501: {'paveh'}
# Processing data for city number 502: {'nador'}
# Processing data for city number 503: {'opobo'}
# No data found for opobo
# Processing data for city number 504: {'cortez'}
# Processing data for city number 505: {'trinidad'}
# Processing data for city number 506: {'yinchuan'}
# Processing data for city number 507: {'ilhabela'}
# Processing data for city number 508: {'hamilton'}
# Processing data for city number 509: {'naco'}
# Processing data for city number 510: {'nhlangano'}
# Processing data for city number 511: {'affery'}
# Processing data for city number 512: {'sunbury'}
# Processing data for city number 513: {'kuntaur'}
# Processing data for city number 514: {'kysyl-syr'}
# Processing data for city number 515: {'gashua'}
# Processing data for city number 516: {'alice springs'}
# Processing data for city number 517: {'hvolsvollur'}
# Processing data for city number 518: {'amurzet'}
# Processing data for city number 519: {'laguna'}
# Processing data for city number 520: {'port lincoln'}
# Processing data for city number 521: {'gazli'}
# Processing data for city number 522: {'chateaubelair'}
# Processing data for city number 523: {'vestmanna'}
# Processing data for city number 524: {'moron'}
# Processing data for city number 525: {'aktash'}
# Processing data for city number 526: {'sunrise manor'}
# Processing data for city number 527: {'iracoubo'}
# Processing data for city number 528: {'tecoanapa'}
# Processing data for city number 529: {'ahuimanu'}
# Processing data for city number 530: {'the pas'}
# Processing data for city number 531: {'niono'}
# Processing data for city number 532: {'balabac'}
# Processing data for city number 533: {'capoterra'}
# Processing data for city number 534: {'hanko'}
# Processing data for city number 535: {'buraydah'}
# Processing data for city number 536: {'fairbanks'}
# Processing data for city number 537: {'king city'}
# Processing data for city number 538: {'luganville'}
# Processing data for city number 539: {'diu'}
# Processing data for city number 540: {'esperance'}
# Processing data for city number 541: {'barcelos'}
# Processing data for city number 542: {'tiarei'}
# Processing data for city number 543: {'arcata'}
# Processing data for city number 544: {'mahon'}
# Processing data for city number 545: {'wanning'}
# Processing data for city number 546: {'mandeville'}
# Processing data for city number 547: {'hokitika'}
# Processing data for city number 548: {'fort nelson'}
# Processing data for city number 549: {'abiy adi'}
# No data found for abiy adi
# Processing data for city number 550: {'maldonado'}
# Processing data for city number 551: {'zhangye'}
# Processing data for city number 552: {'golden'}
# Processing data for city number 553: {'byron bay'}
# Processing data for city number 554: {'begun'}
# Processing data for city number 555: {'gunjur'}
# Processing data for city number 556: {'blackwater'}
# Processing data for city number 557: {'abalak'}
# Processing data for city number 558: {'talcahuano'}
# Processing data for city number 559: {'fukue'}
# Processing data for city number 560: {'kurya'}
# Processing data for city number 561: {'porbandar'}
# Processing data for city number 562: {'lichinga'}
# Processing data for city number 563: {'chunhuhub'}
# Processing data for city number 564: {'tiznit'}
# Processing data for city number 565: {'vilyuysk'}
# Processing data for city number 566: {'eskasem'}
# No data found for eskasem
# Processing data for city number 567: {'esmeraldas'}
# Processing data for city number 568: {'atambua'}
# Processing data for city number 569: {'huatulco'}
# Processing data for city number 570: {'batagay'}
# Processing data for city number 571: {'assomada'}
# Processing data for city number 572: {'chubbuck'}
# Processing data for city number 573: {'murwillumbah'}
# Processing data for city number 574: {'cabadiangan'}
# Processing data for city number 575: {'port hardy'}
# Processing data for city number 576: {'tateyama'}
# Processing data for city number 577: {'kishapu'}
# Processing data for city number 578: {'viseu'}
# Processing data for city number 579: {'nouadhibou'}
# Processing data for city number 580: {'rafai'}
# Processing data for city number 581: {'iwanai'}
# Processing data for city number 582: {'isiolo'}
# Processing data for city number 583: {'sosnovka'}
# Processing data for city number 584: {'fevralsk'}
# No data found for fevralsk
# Processing data for city number 585: {'gorontalo'}
# Processing data for city number 586: {'vanavara'}
# Processing data for city number 587: {'hecun'}
# Processing data for city number 588: {'samfya'}
# Processing data for city number 589: {'remanso'}
# Processing data for city number 590: {'lata'}
# Processing data for city number 591: {'sorland'}
# Processing data for city number 592: {'muros'}
# Processing data for city number 593: {'kuching'}
# Processing data for city number 594: {'sao geraldo do araguaia'}
# Processing data for city number 595: {'nanzhou'}
# Process complete

# %% [markdown]
# #### Pandas Data Frame

# %%
city_df = pd.DataFrame(city_data)
city_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      olinda  -8.0089  -34.8553     82.40        65          20       11.50
# 1    pochutla  15.7432  -96.4661     87.01        54           1        9.22
# 2    tamiahua  21.2667  -97.4500     63.27        69          81        6.58
# 3        chuy -33.6971  -53.4616     73.33        59          41        4.38
# 4  butaritari   3.0707  172.7902     80.65        81         100       15.19
#
#   Country        Date
# 0      BR  1613847427
# 1      MX  1613847660
# 2      MX  1613847660
# 3      UY  1613847669
# 4      KI  1613847377

# %%
city_df.count()
# Out:
# City          546
# Lat           546
# Lng           546
# Max Temp      546
# Humidity      546
# Cloudiness    546
# Wind Speed    546
# Country       546
# Date          546
# dtype: int64

# %%
lats = city_df["Lat"]
max_temps = city_df["Max Temp"]
humidity = city_df["Humidity"]
cloudiness = city_df["Cloudiness"]
wind_speed = city_df["Wind Speed"]

# %%
max(humidity)
# Out:
# 100

# %% [markdown]
# #### Temperature (F) vs. Latitude

# %%
plt.scatter(lats, max_temps)
plt.title('Temperature vs. City Latitude')
plt.xlabel('Latitude')
plt.ylabel('Temperature °F')
plt.grid(True)
plt.savefig('lat_temp.png', bbox_inches='tight')

# %% [markdown]
# #### Humidity (%) vs. Latitude

# %%
plt.scatter(lats, humidity)
plt.title('City Humidity vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(True)
plt.savefig('hum_lat.png',bbox_inches='tight')

# %% [markdown]
# #### Cloudiness (%) vs. Latitude

# %%
plt.scatter(lats, cloudiness)
plt.title('Cloudiness vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(True)
plt.savefig('cloud_lat.png',bbox_inches='tight')

# %% [markdown]
# #### Wind Speed (mph) vs. Latitude

# %%
plt.scatter(lats, wind_speed)
plt.title('Wind Speed (mph) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)
plt.savefig('wind_lats.png',bbox_inches='tight')

# %% [markdown]
# #### Linear Regression

# %%
def linear_regression(x_values, y_values, title, text_coordinates):    
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
north_hemi_df = city_df.loc[(city_df["Lat"] >= 0)]
south_hemi_df = city_df.loc[(city_df["Lat"] < 0)]

# %% [markdown]
# #### Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Max Temp"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.761297798520629

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Max Temp"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.3959529372997825

# %% [markdown]
# #### Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Humidity"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.19023082986480186

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Humidity"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.01802061334920062

# %% [markdown]
# #### Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Cloudiness"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.05296396734671641

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Cloudiness"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.18236416319895687

# %% [markdown]
# ####  Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hemi_df["Lat"]
y_values = north_hemi_df["Wind Speed"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.00041528890222136336

# %%
x_values = south_hemi_df["Lat"]
y_values = south_hemi_df["Wind Speed"]
linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.00018008067646695862
