# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
db_path = '../../git_resources/08-Sqlalchemy-challenge/hawaii.sqlite'
engine = create_engine(f"sqlite:///{db_path}")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine = engine, reflect = True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(bind = engine)

# %%
inspector = inspect(engine)

# %%
for c in inspector.get_columns('Measurement'):
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
for c in inspector.get_columns('Station'):
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %% [markdown]
# # Exploratory Climate Analysis
#
# ### Measurement

# %% [markdown]
# `Design a query to retrieve last 12 months of precipitation data and plot the results` <br><br>
# `Calculate the date 1 year ago from the last data point in the database`

# %%
# last date in data set
last_date = (session.query(Measurement.date)
              .order_by(Measurement.date.desc())
              .first())

# subtract 365(12 months) from latest date 
one_year = dt.date(2017,8,23) - dt.timedelta(days=365)

print(last_date)
print(one_year)
# Out:
# ('2017-08-23',)
# 2016-08-23

# %% [markdown]
# `Perform a query to retrieve the data and precipitation scores`

# %%
one_year = (session.query(Measurement.date, Measurement.prcp)
                 .filter(Measurement.date >= one_year)
                 .order_by(Measurement.date.asc())
                 .all())

one_year
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-23', 0.15),
#  ('2016-08-23', 0.05),
#  ('2016-08-23', None),
#  ('2016-08-23', 0.02),
#  ('2016-08-23', 1.79),
#  ('2016-08-23', 0.7),
#  ('2016-08-24', 0.08),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 2.28),
#  ('2016-08-24', None),
#  ('2016-08-24', 1.22),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 1.45),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.21),
#  ('2016-08-25', 0.06),
#  ('2016-08-25', 0.11),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.03),
#  ('2016-08-26', 0.02),
#  ('2016-08-26', 0.04),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.01),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.18),
#  ('2016-08-27', 0.02),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.12),
#  ('2016-08-27', None),
#  ('2016-08-28', 0.01),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.6),
#  ('2016-08-28', 2.07),
#  ('2016-08-29', 0.0),
# ...

# %% [markdown]
# **Pandas DataFrame**<br><br>
# `Save the query results as a Pandas DataFrame` <br>
# `Clean data (drop empty values)`

# %%
prcp_df = pd.DataFrame(data = one_year, columns = ['Date','Precipitation'])
prcp_df.dtypes
# Out:
# Date              object
# Precipitation    float64
# dtype: object

# %%
prcp_df.count()
# Out:
# Date             2230
# Precipitation    2021
# dtype: int64

# %%
# # ‘any’ : If any NA values are present, drop that row or column.
prcp_df.dropna(how='any', inplace = True)

# %%
prcp_df.count()
# Out:
# Date             2021
# Precipitation    2021
# dtype: int64

# %% [markdown]
# `Set the index to the date column`

# %%
prcp_df.set_index('Date', inplace=True)
prcp_df.head()
# Out:
#             Precipitation
# Date
# 2016-08-23           0.00
# 2016-08-23           0.15
# 2016-08-23           0.05
# 2016-08-23           0.02
# 2016-08-23           1.79

# %% [markdown]
# `Sort the dataframe by date`

# %%
prcp_df.sort_index(ascending = True, inplace = True)
prcp_df
# Out:
#             Precipitation
# Date
# 2016-08-23           0.00
# 2016-08-23           0.15
# 2016-08-23           0.05
# 2016-08-23           0.02
# 2016-08-23           1.79
# ...                   ...
# 2017-08-22           0.50
# 2017-08-23           0.00
# 2017-08-23           0.00
# 2017-08-23           0.08
# 2017-08-23           0.45
#
# [2021 rows x 1 columns]

# %% [markdown]
# `Use Pandas Plotting with Matplotlib to plot the data`

# %%
max_prcp = prcp_df['Precipitation'].max()
max_prcp
# Out:
# 6.7

# %%
prcp_df.plot(kind = 'bar', figsize = (20,3), title = 'Precipication Analysis')

plt.ylabel('Inches')
plt.ylim(0, max_prcp)

plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# `Matplotlib`

# %%
new_prcp_df = pd.DataFrame(data = one_year, columns = ['Date','Precipitation'])
new_prcp_df.dropna(how='any', inplace = True)

# %%
new_prcp_df.head()
# Out:
#          Date  Precipitation
# 0  2016-08-23           0.00
# 1  2016-08-23           0.15
# 2  2016-08-23           0.05
# 4  2016-08-23           0.02
# 5  2016-08-23           1.79

# %%
x_axis = np.arange(len(new_prcp_df))
tick_locations = [value for value in x_axis]

# %%
plt.figure(figsize=(20,3))
plt.bar(x_axis, new_prcp_df['Precipitation'], color = 'r', alpha = 0.5, align = 'center')
plt.xticks(tick_locations, new_prcp_df['Date'], rotation = "vertical")


plt.xlim(-.50, len(x_axis))
plt.ylim(0, max_prcp)

plt.title("Precipication Analysis")
plt.xlabel("Date")
plt.ylabel('Inches')

plt.tight_layout
plt.show()

# %% [markdown]
# `Use Pandas to calcualte the summary statistics for the precipitation data`
#
# **Note: I used Pandas describe to get an overall summary of the data, but i also divided the data into seasons and created a new dataframe to reflect my findings.**

# %%
prcp_df.describe()
# Out:
#        Precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
x = prcp_df.sort_index(ascending = True)
x.head(1)
# Out:
#             Precipitation
# Date
# 2016-08-23            0.0

# %%
y = prcp_df.sort_index(ascending = False)
y.head(1)
# Out:
#             Precipitation
# Date
# 2017-08-23           0.45

# %% [markdown]
# ### Season Time Frames
#
# **Summer**&emsp;&emsp;&emsp;&emsp;Aug 23, 2016 - Aug 31, 2016<br>
# **Fall**&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;Sept 01, 2016 - Nov 31, 2016 <br>
# **Winter**&emsp;&emsp;&emsp;&emsp;&emsp;Dec 01, 2017 - Feb 28, 2017 <br>
# **Spring**&emsp;&emsp;&emsp;&emsp;&emsp;Mar 1, 2017 - Apr 30, 2017 <br>
# **Summer**&emsp;&emsp;&emsp;&emsp;June 1 2017 to Aug 23, 2017 <br>

# %%
fall_2016 = (session.query(Measurement.date, Measurement.prcp)
             .filter(Measurement.date >= '2016-09-01')
             .filter(Measurement.date <= '2016-11-31')
             .order_by(Measurement.date.asc())
             .all())

winter_2016 = (session.query(Measurement.date, Measurement.prcp)
             .filter(Measurement.date >= '2016-12-01')
             .filter(Measurement.date <= '2017-02-29')
             .order_by(Measurement.date.asc())
             .all())

spring_2017 = (session.query(Measurement.date, Measurement.prcp)
             .filter(Measurement.date >= '2017-03-01')
             .filter(Measurement.date <= '2017-05-31')
             .order_by(Measurement.date.asc())
             .all())

summer_2017 = (session.query(Measurement.date, Measurement.prcp)
             .filter(Measurement.date >= '2017-06-01')
             .filter(Measurement.date <= '2017-08-31')
             .order_by(Measurement.date.asc())
             .all())

fall2016_df = pd.DataFrame(data = fall_2016, columns = ['Date','Precipitation'])
winter2016_df = pd.DataFrame(data = winter_2016, columns = ['Date','Precipitation'])
spring2017_df = pd.DataFrame(data = spring_2017, columns = ['Date','Precipitation'])
summer2017_df = pd.DataFrame(data = summer_2017, columns = ['Date','Precipitation'])

fall2016_df.dropna(how='any', inplace = True)
winter2016_df.dropna(how='any', inplace = True)
spring2017_df.dropna(how='any', inplace = True)
summer2017_df.dropna(how='any', inplace = True)

# %%
f_min = fall2016_df['Precipitation'].mean()
w_min = winter2016_df['Precipitation'].mean()
sp_min = spring2017_df['Precipitation'].mean()
su_min = summer2017_df['Precipitation'].mean()

f_max= fall2016_df['Precipitation'].max()
w_max= winter2016_df['Precipitation'].max()
sp_max = spring2017_df['Precipitation'].max()
su_max = summer2017_df['Precipitation'].max()

f_mean= fall2016_df['Precipitation'].mean()
w_mean= winter2016_df['Precipitation'].mean()
sp_mean = spring2017_df['Precipitation'].mean()
su_mean= summer2017_df['Precipitation'].mean()

f_std= fall2016_df['Precipitation'].std()
w_std= winter2016_df['Precipitation'].std()
sp_std = spring2017_df['Precipitation'].std()
su_std= summer2017_df['Precipitation'].std()

prcp_min = [f_min, w_min, sp_min, su_min]
prcp_max = [f_max, w_max, sp_max, su_max]
prcp_mean = [f_mean, w_mean, sp_mean, su_mean]
prcp_std = [f_std, w_std, sp_std, su_std]

# %%
seasons = ['Fall 2016', 'Winter 2016', 'Spring 2017', 'Summer 2017']

prcp_stats = pd.DataFrame({'Season/Year Precipitation': seasons,
                          'Min': prcp_min,
                          'Max': prcp_max,
                          'Average':prcp_mean,
                          'Std Dev':prcp_std})

prcp_stats.set_index('Season/Year Precipitation', inplace = True)
prcp_stats
# Out:
#                                 Min   Max   Average   Std Dev
# Season/Year Precipitation
# Fall 2016                  0.175392  6.70  0.175392  0.478847
# Winter 2016                0.169647  5.04  0.169647  0.463324
# Spring 2017                0.216568  6.25  0.216568  0.515568
# Summer 2017                0.115467  4.00  0.115467  0.289144

# %% [markdown]
# ### Stations

# %%
for c in inspector.get_columns('Station'):
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
for c in inspector.get_columns('Measurement'):
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %% [markdown]
# `Design a query to show how many stations are available in this dataset?`

# %%
total_stations = (session.query(Station.station)).count()
print(f'{total_stations} total stations')
# Out:
# 9 total stations

# %%
total_stations2 = (session.query(Measurement.station)).all()
ts2_df = pd.DataFrame(data = total_stations2, columns = ['Station'])
ts2_df.nunique()
# Out:
# Station    9
# dtype: int64

# %% [markdown]
# `Design a query to find:`
# <br>
# <br>
# `What are the most active stations? (i.e. what stations have the most rows)?`
# <br>
# <br>
# `List the stations and the counts in descending order.`

# %%
station_activity = ts2_df['Station'].value_counts()
station_activity
# Out:
# USC00519281    2772
# USC00519397    2724
# USC00513117    2709
# USC00519523    2669
# USC00516128    2612
# USC00514830    2202
# USC00511918    1979
# USC00517948    1372
# USC00518838     511
# Name: Station, dtype: int64

# %% [markdown]
# `Using the station id from the previous query...`<br>
# `calculate the lowest temperature recorded, highest temperature recorded, and avg temperature`

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
lowest_temp = session.query(func.min(Measurement.tobs)).filter(Measurement.station == 'USC00519281').all()
max_temp = session.query(func.max(Measurement.tobs)).filter(Measurement.station == 'USC00519281').all()
avg_temp = session.query(func.avg(Measurement.tobs)).filter(Measurement.station == 'USC00519281').all()

print(f'Lowest Temp:{lowest_temp}')
print(f'Highest Temp: {max_temp}')
print(f'Avg Temp: {avg_temp}')
# Out:
# Lowest Temp:[(54.0,)]
# Highest Temp: [(85.0,)]
# Avg Temp: [(71.66378066378067,)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# USC00519281

tobs_highest = (session.query(Measurement.date, Measurement.tobs)
                .filter(Measurement.station=='USC00519281')
                .filter(Measurement.date >= '2016-08-23')).all()


tobs_highest
# Out:
# [('2016-08-23', 77.0),
#  ('2016-08-24', 77.0),
#  ('2016-08-25', 80.0),
#  ('2016-08-26', 80.0),
#  ('2016-08-27', 75.0),
#  ('2016-08-28', 73.0),
#  ('2016-08-29', 78.0),
#  ('2016-08-30', 77.0),
#  ('2016-08-31', 78.0),
#  ('2016-09-01', 80.0),
#  ('2016-09-02', 80.0),
#  ('2016-09-03', 78.0),
#  ('2016-09-04', 78.0),
#  ('2016-09-05', 78.0),
#  ('2016-09-06', 73.0),
#  ('2016-09-07', 74.0),
#  ('2016-09-08', 80.0),
#  ('2016-09-09', 79.0),
#  ('2016-09-10', 77.0),
#  ('2016-09-11', 80.0),
#  ('2016-09-12', 76.0),
#  ('2016-09-13', 79.0),
#  ('2016-09-14', 75.0),
#  ('2016-09-15', 79.0),
#  ('2016-09-16', 78.0),
#  ('2016-09-17', 79.0),
#  ('2016-09-18', 78.0),
#  ('2016-09-19', 78.0),
#  ('2016-09-20', 76.0),
#  ('2016-09-21', 74.0),
#  ('2016-09-22', 77.0),
#  ('2016-09-23', 78.0),
#  ('2016-09-24', 79.0),
#  ('2016-09-25', 79.0),
#  ('2016-09-26', 77.0),
#  ('2016-09-27', 80.0),
#  ('2016-09-28', 78.0),
#  ('2016-09-29', 78.0),
#  ('2016-09-30', 78.0),
#  ('2016-10-01', 77.0),
# ...

# %% [markdown]
# ## Bonus Challenge Assignment

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

# %%
# Plot the daily normals as an area plot with `stacked=False`
